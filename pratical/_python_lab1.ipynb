# %% [markdown]
# <a href="https://colab.research.google.com/github/battinachandrika7-star/2520030047_ml/blob/main/%20practical%20/%20python_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a Python program to declare variables of type int, float, string, and boolean, and display their values along with their data types.
x = 5
y = 3.14
name = "CGPA"
is_placed = True

print(x)
print(type(x))
print(y)
print(type(y))
print(name)
print(type(name))
print(is_placed)
print(type(is_placed))
# Out:
# 5
# <class 'int'>
# 3.14
# <class 'float'>
# CGPA
# <class 'str'>
# True
# <class 'bool'>

# %%
#Write a program to check the data type of different variables using the type() function.
age = 25
name = "Alex"
is_student = True

print(type(age))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %%
model_name = "Logistic Regression"
accuracy = 0.87345

# Old, clunky way (avoid this):
print("Accuracy of " + model_name + " is " + str(accuracy))

# f-string way (use this):
print(f"Accuracy of {model_name} is {accuracy}")

# ':.3f' inside the braces rounds a float to 3 decimal places -
# you will use this in almost every experiment to print clean metrics.
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.873

# %%
# --- LISTS & INDEXING ---

features = ["CGPA", "AptitudeTestScore", "CodingTestScore", "MockInterviewScore"]

print(features)
print(features[0])
print(features[1])
print(features[-1])
print(len(features))

# Slicing:
print(features[0:2])

# Adding to a list
features.append("Internships")
print(features)
# Out:
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore']
# CGPA
# AptitudeTestScore
# MockInterviewScore
# 4
# ['CGPA', 'AptitudeTestScore']
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore', 'Internships']

# %%
# Create a dictionary
student = {
    "Name": "chandrika",
    "Roll No": 47,
    "CGPA": 9.2
}

# Display all key-value pairs
print("Student Details:")
for key, value in student.items():
    print(key, ":", value)

# Access a specific key
print("\nStudent Name:", student["Name"])

# Machine Learning models dictionary
ml_models = {
    "Linear Regression": "Regression",
    "Decision Tree": "Classification",
    "Random Forest": "Ensemble"
}

print("\nMachine Learning Models:")
for model, model_type in ml_models.items():
    print(model, ":", model_type)
# Out:
# Student Details:
# Name : chandrika
# Roll No : 47
# CGPA : 9.2
#
# Student Name: chandrika
#
# Machine Learning Models:
# Linear Regression : Regression
# Decision Tree : Classification
# Random Forest : Ensemble

# %%
# Program 6: Conditional Statements

# 1. Classify student's CGPA
cgpa = 8.3

if cgpa >= 8.5:
    print("Category: High")
elif cgpa >= 6.5:
    print("Category: Mid")
else:
    print("Category: Low")

# 2. Check for missing values in a dataset
data = [10, 20, None, 40]

if None in data:
    print("Missing values are present.")
else:
    print("No missing values.")

# 3. Check placement eligibility
if cgpa >= 7.0:
    print("Student is Eligible for Placement.")
else:
    print("Student is Not Eligible for Placement.")

# 4. Assign grades based on marks
marks = int(input("Enter Marks: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
elif marks >= 40:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Category: Mid
# Missing values are present.
# Student is Eligible for Placement.
# Enter Marks: 90
# Grade: A
