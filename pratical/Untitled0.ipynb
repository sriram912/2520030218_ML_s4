# %% [markdown]
# <a href="https://colab.research.google.com/github/sriram912/2520030218_ML_s4/blob/main/pratical/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
a=0.9
b=3.5
c=9+78j
print(a+b)
print("hexevalue of a",int(a))
print("Binary value of a",int(a))
print(" Integer value of a",int(a))
a=12
b=5
print("a//b")
print(a*b)
print(a+b)
print(a-b)
a=10
b=20
print(a>b)
x=true
y=False
print(x and y)
print(x or y )
# Out:
# hello world
# 4.4
# hexevalue of a 0
# Binary value of a 0
#  Integer value of a 0
# a//b
# 60
# 17
# 7
# False
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12638/1997662260.py in <cell line: 0>()
#      16 b=20
#      17 print(a>b)
# ---> 18 x=true
#      19 y=False
#      20 print(x and y)
#
# NameError: name 'true' is not defined
