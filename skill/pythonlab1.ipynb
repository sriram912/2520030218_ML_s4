# %%
x=5
y=3.14
age = 18
height = 5.11
name = "Sriram"
is_student = True
complex_num = 3 + 4j

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Student:", is_student)
print("Complex Number:", complex_num)

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
print(type(complex_num))
# Out:
# Name: Sriram
# Age: 18
# Height: 5.9
# Student: True
# Complex Number: (3+4j)
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>
